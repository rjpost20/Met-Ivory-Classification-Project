# %%
import requests

# %%
r = requests.get("https://collectionapi.metmuseum.org/public/collection/v1/objects")

# %%
test1 = requests.get('https://collectionapi.metmuseum.org/public/collection/v1/objects/500')

# %%
test1.json()
# Out:
# {'objectID': 500,
#  'isHighlight': False,
#  'accessionNumber': '83.2.251',
#  'accessionYear': '1883',
#  'isPublicDomain': True,
#  'primaryImage': 'https://images.metmuseum.org/CRDImages/ad/original/25656.jpg',
#  'primaryImageSmall': 'https://images.metmuseum.org/CRDImages/ad/web-large/25656.jpg',
#  'additionalImages': [],
#  'constituents': None,
#  'department': 'The American Wing',
#  'objectName': 'Painting',
#  'title': 'Portrait of Benjamin Franklin',
#  'culture': '',
#  'period': '',
#  'dynasty': '',
#  'reign': '',
#  'portfolio': '',
#  'artistRole': '',
#  'artistPrefix': '',
#  'artistDisplayName': '',
#  'artistDisplayBio': '',
#  'artistSuffix': '',
#  'artistAlphaSort': '',
#  'artistNationality': '',
#  'artistBeginDate': '',
#  'artistEndDate': '',
#  'artistGender': '',
#  'artistWikidata_URL': '',
#  'artistULAN_URL': '',
#  'objectDate': '1800–1883',
#  'objectBeginDate': 1800,
#  'objectEndDate': 1883,
#  'medium': 'Silk',
# ...

# %%
test2 = requests.get('https://collectionapi.metmuseum.org/public/collection/v1/search?hasImages=true&q=Auguste Renoir')

# %%
test2.json()
# Out:
# {'total': 145,
#  'objectIDs': [438815,
#   438011,
#   437432,
#   438014,
#   437430,
#   459110,
#   459112,
#   459111,
#   438012,
#   438013,
#   437437,
#   459113,
#   438010,
#   437428,
#   437426,
#   437429,
#   437425,
#   441104,
#   437436,
#   437424,
#   437135,
#   264858,
#   436965,
#   201585,
#   490026,
#   459967,
#   459971,
#   459968,
#   459970,
#   459969,
#   459109,
#   437438,
#   459966,
#   437439,
#   358923,
#   437431,
#   437427,
#   437434,
#   339677,
#   339674,
#   437433,
#   437435,
#   358770,
#   358926,
#   358922,
#   339678,
#   358927,
#   364095,
#   358929,
#   191807,
#   358765,
#   722444,
#   436703,
#   336671,
#   488710,
#   333817,
#   19294,
#   364093,
#   436132,
#   436706,
#   436947,
#   437317,
#   437133,
#   10915,
#   19335,
#   436534,
#   437680,
#   284452,
#   285444,
#   436958,
#   436175,
#   436960,
#   435868,
#   437301,
#   438823,
#   438005,
#   438820,
#   437313,
#   436945,
#   437136,
#   436123,
# ...

# %%
test2.[436127].json()
# Out:
#   Input In [20]
#     test2.[436127].json()
#           ^
# SyntaxError: invalid syntax
